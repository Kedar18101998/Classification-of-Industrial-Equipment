# %% [markdown]
# For this example, I'll use the CIFAR-10 dataset, which contains 60,000 32x32 color images in 10 different classes, such as 'airplane', 'automobile', 'bird', etc. We'll adapt it to our binary classification problem by considering 'airplane' images as 'defective' and all other classes as 'non-defective'.

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import numpy as np

# %%
# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
# Preprocess the data
def preprocess_data(images, labels):
    # Normalize pixel values to be between 0 and 1
    images = images / 255.0
    # Convert labels to binary: 1 for 'airplane' (defective), 0 for other classes (non-defective)
    labels = np.where(labels == 0, 1, 0)
    return images, labels

# %%
train_images, train_labels = preprocess_data(train_images, train_labels)
test_images, test_labels = preprocess_data(test_images, test_labels)

# %%
# Build the model
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid')) # Output layer for binary classification

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(train_images, train_labels, epochs=10,
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 74s 46ms/step - loss: 0.2377 - accuracy: 0.9133 - val_loss: 0.1943 - val_accuracy: 0.9274
# Epoch 2/10
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.1919 - accuracy: 0.9268 - val_loss: 0.1726 - val_accuracy: 0.9347
# Epoch 3/10
# 1563/1563 [==============================] - 65s 42ms/step - loss: 0.1669 - accuracy: 0.9381 - val_loss: 0.1611 - val_accuracy: 0.9394
# Epoch 4/10
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.1513 - accuracy: 0.9437 - val_loss: 0.1617 - val_accuracy: 0.9399
# Epoch 5/10
# 1563/1563 [==============================] - 63s 41ms/step - loss: 0.1382 - accuracy: 0.9481 - val_loss: 0.1525 - val_accuracy: 0.9425
# Epoch 6/10
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.1273 - accuracy: 0.9517 - val_loss: 0.1553 - val_accuracy: 0.9424
# Epoch 7/10
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.1168 - accuracy: 0.9556 - val_loss: 0.1505 - val_accuracy: 0.9477
# Epoch 8/10
# 1563/1563 [==============================] - 65s 42ms/step - loss: 0.1077 - accuracy: 0.9596 - val_loss: 0.1415 - val_accuracy: 0.9483
# Epoch 9/10
# 1563/1563 [==============================] - 65s 42ms/step - loss: 0.0962 - accuracy: 0.9637 - val_loss: 0.1499 - val_accuracy: 0.9492
# Epoch 10/10
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.0875 - accuracy: 0.9671 - val_loss: 0.1528 - val_accuracy: 0.9451

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 4s 12ms/step - loss: 0.1528 - accuracy: 0.9451

# %%
print('Test accuracy:', test_acc)
# Out:
# Test accuracy: 0.9451000094413757

# %%
from sklearn.metrics import precision_score, recall_score

# %%
# Predict on the test set
predictions = (model.predict(test_images) > 0.5).astype("int32")
# Out:
# 313/313 [==============================] - 4s 11ms/step

# %%
# Calculate precision and recall
precision = precision_score(test_labels, predictions)
recall = recall_score(test_labels, predictions)

# %%
print('Precision:', precision)
print('Recall:', recall)
print('Test accuracy:', test_acc)
# Out:
# Precision: 0.711737089201878
# Recall: 0.758
# Test accuracy: 0.9451000094413757
